# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
import numpy as np

# %%
data=pd.read_csv(r"C:\Users\tript\OneDrive\Desktop\internsip\04_monthly_sip_inflows.csv")

# %%
data
# Out:
#       month  sip_inflow_crore  active_sip_accounts_crore  \
# 0   2022-01             11517                       4.91
# 1   2022-02             11438                       4.93
# 2   2022-03             12328                       5.09
# 3   2022-04             11863                       5.48
# 4   2022-05             12286                       5.55
# 5   2022-06             12276                       5.60
# 6   2022-07             12140                       5.65
# 7   2022-08             12694                       5.71
# 8   2022-09             12976                       5.80
# 9   2022-10             13040                       5.93
# 10  2022-11             13306                       6.00
# 11  2022-12             13573                       6.05
# 12  2023-01             13856                       6.13
# 13  2023-02             13687                       6.19
# 14  2023-03             14276                       6.32
# ...

# %%
data.info(  )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   month                      48 non-null     object
#  1   sip_inflow_crore           48 non-null     int64
#  2   active_sip_accounts_crore  48 non-null     float64
#  3   new_sip_accounts_lakh      48 non-null     float64
#  4   sip_aum_lakh_crore         48 non-null     float64
#  5   yoy_growth_pct             36 non-null     float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 2.4+ KB

# %%
data.describe()
# Out:
#        sip_inflow_crore  active_sip_accounts_crore  new_sip_accounts_lakh  \
# count         48.000000                  48.000000              48.000000
# mean       19577.520833                   7.189583               9.893750
# std         6354.329621                   1.271457               5.370745
# min        11438.000000                   4.910000               7.500000
# 25%        13658.500000                   6.110000               8.775000
# 50%        18224.000000                   7.150000               9.200000
# 75%        25944.250000                   8.300000               9.562500
# max        31002.000000                   9.350000              46.000000
#
#        sip_aum_lakh_crore  yoy_growth_pct
# count           48.000000       36.000000
# mean             8.632083       31.456944
# std              3.613579       11.768190
# min              4.800000       15.800000
# 25%              5.790000       20.245000
# 50%              7.265000       28.295000
# ...

# %%
data.isnull().sum()
# Out:
# month                         0
# sip_inflow_crore              0
# active_sip_accounts_crore     0
# new_sip_accounts_lakh         0
# sip_aum_lakh_crore            0
# yoy_growth_pct               12
# dtype: int64

# %%
data.columns
# Out:
# Index(['month', 'sip_inflow_crore', 'active_sip_accounts_crore',
#        'new_sip_accounts_lakh', 'sip_aum_lakh_crore', 'yoy_growth_pct'],
#       dtype='object')

# %%
data.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# dtype: bool

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data["month"].head(10)
# Out:
# 0    2022-01
# 1    2022-02
# 2    2022-03
# 3    2022-04
# 4    2022-05
# 5    2022-06
# 6    2022-07
# 7    2022-08
# 8    2022-09
# 9    2022-10
# Name: month, dtype: object

# %%
data["month"] = pd.to_datetime(data["month"])

# %%
data["month"].head(10)
# Out:
# 0   2022-01-01
# 1   2022-02-01
# 2   2022-03-01
# 3   2022-04-01
# 4   2022-05-01
# 5   2022-06-01
# 6   2022-07-01
# 7   2022-08-01
# 8   2022-09-01
# 9   2022-10-01
# Name: month, dtype: datetime64[ns]

# %%
data[data["yoy_growth_pct"].isnull()]
# Out:
#         month  sip_inflow_crore  active_sip_accounts_crore  \
# 0  2022-01-01             11517                       4.91
# 1  2022-02-01             11438                       4.93
# 2  2022-03-01             12328                       5.09
# 3  2022-04-01             11863                       5.48
# 4  2022-05-01             12286                       5.55
# 5  2022-06-01             12276                       5.60
# 6  2022-07-01             12140                       5.65
# 7  2022-08-01             12694                       5.71
# 8  2022-09-01             12976                       5.80
# 9  2022-10-01             13040                       5.93
# 10 2022-11-01             13306                       6.00
# 11 2022-12-01             13573                       6.05
#
#     new_sip_accounts_lakh  sip_aum_lakh_crore  yoy_growth_pct
# 0                    9.10                4.80             NaN
# 1                    8.20                4.85             NaN
# ...

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
(data["sip_inflow_crore"] < 0).sum()
# Out:
# np.int64(0)

# %%
(data["active_sip_accounts_crore"] < 0).sum()
# Out:
# np.int64(0)

# %%
(data["new_sip_accounts_lakh"] < 0).sum()
# Out:
# np.int64(0)

# %%
(data["sip_aum_lakh_crore"] < 0).sum()
# Out:
# np.int64(0)

# %%
numeric_cols = [
    "sip_inflow_crore",
    "active_sip_accounts_crore",
    "new_sip_accounts_lakh",
    "sip_aum_lakh_crore",
    "yoy_growth_pct"
]

for col in numeric_cols:
    plt.figure(figsize=(6,3))
    plt.boxplot(data[col].dropna())
    plt.title(col)
    plt.show()

# %%
data[data["new_sip_accounts_lakh"] > 20]
# Out:
#         month  sip_inflow_crore  active_sip_accounts_crore  \
# 39 2025-04-01             26632                       8.38
#
#     new_sip_accounts_lakh  sip_aum_lakh_crore  yoy_growth_pct
# 39                   46.0               13.55           30.73

# %%
data.to_csv("04_monthly_sip_inflows_clean.csv", index=False)
