# %%
pip install sqlalchemy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sqlalchemy in C:\Users\tript\AppData\Roaming\Python\Python314\site-packages (2.0.49)
# Requirement already satisfied: greenlet>=1 in C:\Users\tript\AppData\Roaming\Python\Python314\site-packages (from sqlalchemy) (3.4.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in C:\Users\tript\AppData\Roaming\Python\Python314\site-packages (from sqlalchemy) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine("sqlite:///bluestock_mf.db")

# %%
# Load Cleaned Datasets

fund_master = pd.read_csv(r"C:\Users\tript\OneDrive\Desktop\internsip\...01_fund-master_clean.csv")

nav_history = pd.read_csv(r"C:\Users\tript\OneDrive\Desktop\internsip\...02_nav_history_clean.csv")

aum = pd.read_csv("03_aum_by_fund_house_clean.csv")

sip = pd.read_csv("04_monthly_sip_inflows_clean.csv")

category = pd.read_csv("05_category_inflows_clean.csv")

folio = pd.read_csv("06_industry_folio_count_clean.csv")

performance = pd.read_csv("07_scheme_performance_clean.csv")

transactions = pd.read_csv("08_investor_transactions_clean.csv")

portfolio = pd.read_csv("09_portfolio_holdings_clean.csv")

benchmark = pd.read_csv("10_benchmark_indices_clean.csv")

# %%
fund_master.to_sql("dim_fund", engine, if_exists="replace", index=False)

nav_history.to_sql("fact_nav", engine, if_exists="replace", index=False)

aum.to_sql("fact_aum", engine, if_exists="replace", index=False)

sip.to_sql("fact_sip", engine, if_exists="replace", index=False)

category.to_sql("fact_category", engine, if_exists="replace", index=False)

folio.to_sql("fact_folio", engine, if_exists="replace", index=False)

performance.to_sql("fact_performance", engine, if_exists="replace", index=False)

transactions.to_sql("fact_transactions", engine, if_exists="replace", index=False)

portfolio.to_sql("fact_portfolio", engine, if_exists="replace", index=False)

benchmark.to_sql("fact_benchmark", engine, if_exists="replace", index=False)
# Out:
# 8050

# %%
import sqlite3

conn = sqlite3.connect("bluestock_mf.db")

cursor = conn.cursor()

cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")

print(cursor.fetchall())
# Out:
# [('dim_fund',), ('fact_nav',), ('fact_aum',), ('fact_sip',), ('fact_category',), ('fact_folio',), ('fact_performance',), ('fact_transactions',), ('fact_portfolio',), ('fact_benchmark',)]

# %%
import sqlite3

conn = sqlite3.connect("bluestock_mf.db")
cursor = conn.cursor()

cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# [('dim_fund',), ('fact_nav',), ('fact_aum',), ('fact_sip',), ('fact_category',), ('fact_folio',), ('fact_performance',), ('fact_transactions',), ('fact_portfolio',), ('fact_benchmark',)]

# %%
import sqlite3

conn = sqlite3.connect("bluestock_mf.db")
cursor = conn.cursor()

query = """
SELECT fund_house, SUM(aum_crore)
FROM fact_aum
GROUP BY fund_house
ORDER BY SUM(aum_crore) DESC
LIMIT 5;
"""

cursor.execute(query)
cursor.fetchall()
# Out:
# [('SBI Mutual Fund', 8491000),
#  ('ICICI Prudential MF', 6293000),
#  ('HDFC Mutual Fund', 5732000),
#  ('Nippon India MF', 3909000),
#  ('Kotak Mahindra MF', 3502000)]

# %%
cursor.execute("""
SELECT fund_house, SUM(aum_crore)
FROM fact_aum
GROUP BY fund_house
ORDER BY SUM(aum_crore) DESC;
""")

cursor.fetchall()
# Out:
# [('SBI Mutual Fund', 8491000),
#  ('ICICI Prudential MF', 6293000),
#  ('HDFC Mutual Fund', 5732000),
#  ('Nippon India MF', 3909000),
#  ('Kotak Mahindra MF', 3502000),
#  ('Aditya Birla Sun Life MF', 3077000),
#  ('UTI Mutual Fund', 2681000),
#  ('Axis Mutual Fund', 2521000),
#  ('Mirae Asset MF', 1561000),
#  ('DSP Mutual Fund', 1409000)]
